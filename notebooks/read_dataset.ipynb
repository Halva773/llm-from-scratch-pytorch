# %%
import pandas as pd
import numpy as np

# %%
filepath = "../dataset/poems.csv"
data = pd.read_csv(filepath)
data = data.dropna(subset=['text'])
print(data.shape)
data.head()
# Out:
# (19302, 3)
#                      writer                                       poem  \
# 1  Лермонтов Михаил Юрьевич                       На серебряные шпоры…
# 2  Лермонтов Михаил Юрьевич                  Вид гор из степей Козлова
# 3  Лермонтов Михаил Юрьевич     К  (О, не скрывай! Ты плакала об нем…)
# 4  Лермонтов Михаил Юрьевич  Жалобы турка (письмо к другу, иностранцу)
# 5  Лермонтов Михаил Юрьевич                              К кн. Л. Г-ой
#
#                                                 text
# 1  На серебряные шпоры\nЯ в раздумии гляжу;\nЗа т...
# 2  Пилигрим\nАллах ли там среди пустыни\nЗастывши...
# 3  О, не скрывай! Ты плакала об нем –\nИ я его лю...
# 4  Ты знал ли дикий край, под знойными лучами,\nГ...
# 5  Когда ты холодно внимаешь\nРассказам горести ч...

# %%
data['length'] = data['text'].str.len()
data.head()
# Out:
#                      writer                                       poem  \
# 1  Лермонтов Михаил Юрьевич                       На серебряные шпоры…
# 2  Лермонтов Михаил Юрьевич                  Вид гор из степей Козлова
# 3  Лермонтов Михаил Юрьевич     К  (О, не скрывай! Ты плакала об нем…)
# 4  Лермонтов Михаил Юрьевич  Жалобы турка (письмо к другу, иностранцу)
# 5  Лермонтов Михаил Юрьевич                              К кн. Л. Г-ой
#
#                                                 text  length
# 1  На серебряные шпоры\nЯ в раздумии гляжу;\nЗа т...     378
# 2  Пилигрим\nАллах ли там среди пустыни\nЗастывши...     673
# 3  О, не скрывай! Ты плакала об нем –\nИ я его лю...     263
# 4  Ты знал ли дикий край, под знойными лучами,\nГ...     567
# 5  Когда ты холодно внимаешь\nРассказам горести ч...     628

# %%
data['length'].sum()
# Out:
# 22809081

# %%
data['text'].str.len().sum()
# Out:
# 22809081

# %%
import sys  
sys.path.insert(1, '..')

from src.bpe import BPE

# %%
bpe = BPE(vocab_size=4000)
whole_text = "\n".join(data['text'])
print("Text formatted. Going to fit tokenizer")
bpe.fit(whole_text)
bpe.save('savepoints/bpe.dill')
# Out:
# Text formatted. Going to fit tokenizer
# Обучено 0 токенов

# %%
loaded_bpe = BPE.load('savepoints/bpe.dill')
decoded = loaded_bpe.decode(tokens)
print(decoded)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 loaded_bpe = BPE.load('data/bpe.dill')
#       2 decoded = loaded_bpe.decode(tokens)
#       3 print(decoded)
#
# File ~\PycharmProjects\LLM_from_scratch\notebooks\..\src\bpe.py:130, in BPE.load(cls, filename)
#     128 @classmethod
#     129 def load(cls, filename):
# --> 130     with open(filename, 'rb') as f:
#     131         obj = dill.load(f)
#     133     print(f"Объект загружен из {filename}")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/bpe.dill'
